# %%
# !git clone https://github.com/sgauthamr2001/cv-session.git
# %cd cv-session/
# Out:
# Cloning into 'cv-session'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 76 (delta 19), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (76/76), done.
# /content/cv-session

# %%
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import numpy as np

# %%
img = cv2.imread('media/einstein.jpg',1)

GB1 = cv2.GaussianBlur(img,(9,9),0)
GB2 = cv2.GaussianBlur(img,(5,5),0)

GBDiff = cv2.absdiff(GB1,GB2)
GBEdge = cv2.cvtColor(GBDiff,cv2.COLOR_BGR2GRAY)

plt.figure(),plt.imshow(img),plt.title('Original')
plt.figure(),plt.imshow(GB1),plt.title('9x9 Gaussian Blur')
plt.figure(),plt.imshow(GB2),plt.title('5x5 Gaussian Blur')
plt.figure(),plt.imshow(GBEdge),plt.title('Edges')
plt.show()
