# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import math
image = cv2.imread('/content/einstein.jpg')
image2=cv2.imread('/content/einstein2.png')
image3=cv2.imread('/content/einstein3.png')
image4=image2-image3
blur_gaus = cv2.GaussianBlur(image,(5,5),2)
blur_gaus2 = cv2.GaussianBlur(image,(9,9),2)
plt.figure(),plt.axis("off"),plt.title("Original Image"),plt.imshow(image)
plt.figure(),plt.axis("off"),plt.title("Blurred Image2"),plt.imshow(blur_gaus)
plt.figure(),plt.axis("off"),plt.title("Blurred Image3"),plt.imshow(blur_gaus2)
plt.figure(),plt.axis("off"),plt.title("edge extended Image"),plt.imshow(image4)
plt.show()

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
roi = cv2.imread('/content/barrel.jpg')
hsv = cv2.cvtColor(roi,cv2.COLOR_BGR2HSV)
target=cv2.VideoCapture('https://youtu.be/A9BVr7kltl8')
while True:
  ret,frame=video.read()
  plt.show()
hsvt = cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
I=cv2.calcHist([hsv],[0,1],None,[170,256],[0,170,0,256])
V=cv2.calcHist([hsvt],[0,1],None,[170,256],[0,170,0,256])
ret,thresh1 = cv2.threshold(frame,127,255,cv2.THRESH_BINARY)
plt.subplot(231),plt.imshow(roi,cmap='gray'),plt.title("Original Image"),plt.axis("off")
plt.subplot(232),plt.imshow(thresh1,cmap='gray'),plt.title("BINARY"),plt.axis("off")
