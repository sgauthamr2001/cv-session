# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('einstein.jpg',0)
#plt.figure(),plt.imshow(img,cmap='gray'),plt.title("Grayscale"),plt.axis("off")
#plt.show()

# %%
blur_gaus1 = cv2.GaussianBlur(img,(9,9),0)
blur_gaus2 = cv2.GaussianBlur(img,(5,5),0)
img1 = np.subtract(blur_gaus1,blur_gaus2)
#test = blur_gaus1 - blur_gaus2
plt.figure(),plt.axis("off"),plt.title("Original"),plt.imshow(img,cmap='gray')
plt.figure(),plt.axis("off"),plt.title("Edge_detect"),plt.imshow(img1)
#plt.figure(),plt.axis("off"),plt.title("Edge_detect"),plt.imshow(test)
plt.show()
