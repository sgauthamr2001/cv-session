# %% [markdown]
# Qn1:

# %%
# %cd /content
# !git clone https://github.com/sgauthamr2001/cv-session.git
# %cd cv-session/
# Out:
# /content
# Cloning into 'cv-session'...
# remote: Enumerating objects: 76, done.
# remote: Total 76 (delta 0), reused 0 (delta 0), pack-reused 76
# Unpacking objects: 100% (76/76), done.
# /content/cv-session

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow
img=cv2.imread("/content/cv-session/media/einstein.jpg",0)#einstein image 
g1=cv2.GaussianBlur(img, (5,5), 0)
g2=cv2.GaussianBlur(img, (9,9), 0)
g=cv2.subtract(g2,g1)
plt.figure(),plt.axis("off"),plt.imshow(g,cmap='gray')
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  (0.0, 1.0, 0.0, 1.0),
#  <matplotlib.image.AxesImage at 0x7f2ab5cf1190>)

# %% [markdown]
# Qn2:

# %%
# %cd /media
# !git clone https://github.com/SivaSankarS365/Assignment-2.git
# %cd Assignment-2
# Out:
# /media
# Cloning into 'Assignment-2'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (5/5), done.
# /media/Assignment-2

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
Br_RGB=cv_readimg=cv2.imread("/media/Assignment-2/Bred.png",1)
Br_HSV=cv2.cvtColor(Br_RGB, cv2.COLOR_BGR2HSV)
cv2_imshow(Br_HSV)
# Out:
# <PIL.Image.Image image mode=RGB size=96x118 at 0x7F2AB5D32D50>

# %%
vid=cv2.VideoCapture("/media/Assignment-2/Vid.mp4")
ret,frame=vid.read()
frame_hsv=cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
cv2_imshow(frame_hsv)
# Out:
# <PIL.Image.Image image mode=RGB size=640x360 at 0x7F2AB5CF1F50>

# %%
hist = cv2.calcHist([img],[0], None, [256], [0,256])
norm = cv2.normalize(Br_HSV,  np.zeros((96,118)), 0, 255, cv2.NORM_MINMAX)
cv2_imshow(norm)
# Out:
# <PIL.Image.Image image mode=RGB size=96x118 at 0x7F2AB5C46290>

# %%
res = cv2.calcBackProject([frame_hsv], [0], norm, [0,256], scale=1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-54-2f049f21969a> in <module>()
#       1
# ----> 2 res = cv2.calcBackProject([frame_hsv], [0], norm, [0,256], scale=1)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/histogram.cpp:1988: error: (-215:Assertion failed) rsz == dims*2 || (rsz == 2 && _1d) || (rsz == 0 && images.depth(0) == CV_8U) in function 'calcBackProject'
